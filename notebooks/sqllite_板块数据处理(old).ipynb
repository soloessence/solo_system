# %%
import numpy as np
import pandas as pd 

from talib import abstract
import tushare as ts   ## handle the stock data from tushare public api 
import akshare as ak  ## akstock api 

from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://solo:solo@localhost:5432/metabase')

## get Tocken from https://waditu.com/user/token, 需要注册, 需要积分
pro = ts.pro_api(token="e2a6daed26e1f5bcc76cf710cf4904ce8e9c5e5e849f59118383e351")

#上市状态： L上市 D退市 P暂停上市，默认L
#data = pro.stock_basic(exchange='', list_status='L', fields='ts_code,symbol,name,area,industry,list_date')

# %%
##https://www.akshare.xyz/zh_CN/latest/data/stock/stock.html#id170

dir(ak)
# Out:
# ['__author__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_get_code_pic',
#  'agoyal_stock_return',
#  'air',
#  'air_city_list',
#  'air_quality_hebei',
#  'air_quality_hist',
#  'air_quality_rank',
#  'air_quality_watch_point',
#  'amac_aoin_info',
#  'amac_fund_abs',
#  'amac_fund_account_info',
#  'amac_fund_info',
#  'amac_fund_sub_info',
#  'amac_futures_info',
#  'amac_manager_cancelled_info',
#  'amac_manager_classify_info',
#  'amac_manager_info',
#  'amac_member_info',
#  'amac_member_sub_info',
#  'amac_person_bond_org_list',
#  'amac_person_fund_org_list',
#  'amac_securities_info',
#  'article',
#  'article_epu_index',
#  'article_ff_crr',
#  'article_oman_rv',
#  'article_oman_rv_short',
#  'article_rlab_rv',
#  'baidu_info_index',
#  'baidu_media_index',
#  'baidu_search_index',
#  'bank',
#  'bank_fjcf_table_detail',
#  'bank_rank_banker',
# ...

# %%
ak_industry = ak.stock_board_industry_name_ths()
ak_industry.to_sql("ak_industry", engine, if_exists='append')

ak_industry
# Out:
#       name                                               url
# 0   半导体及元件  http://q.10jqka.com.cn/thshy/detail/code/881121/
# 1     白色家电  http://q.10jqka.com.cn/thshy/detail/code/881131/
# 2    保险及其他  http://q.10jqka.com.cn/thshy/detail/code/881156/
# 3     包装印刷  http://q.10jqka.com.cn/thshy/detail/code/881138/
# 4     采掘服务  http://q.10jqka.com.cn/thshy/detail/code/881107/
# ..     ...                                               ...
# 61      证券  http://q.10jqka.com.cn/thshy/detail/code/881157/
# 62      中药  http://q.10jqka.com.cn/thshy/detail/code/881141/
# 63    专用设备  http://q.10jqka.com.cn/thshy/detail/code/881118/
# 64      造纸  http://q.10jqka.com.cn/thshy/detail/code/881137/
# 65  种植业与林业  http://q.10jqka.com.cn/thshy/detail/code/881101/
#
# [66 rows x 2 columns]

# %%
df = ak.stock_board_industry_cons_ths(symbol="造纸")
df
# Out:
# 100%|██████████| 2/2 [00:00<00:00,  7.23it/s]
#     序号      代码    名称     现价   涨跌幅    涨跌    涨速     换手    量比    振幅     成交额  \
# 0    1  603165  荣晟环保  14.90  4.05  0.58 -0.87   5.55  1.55  8.87   2.10亿
# 1    2  603733  仙鹤股份  27.42  2.12  0.57 -0.04   1.49  1.84  5.55   2.89亿
# 2    3  600963  岳阳林纸   8.19  0.49  0.04  0.12  13.76  1.41  9.45  20.88亿
# 3    4  603863  松炀资源   8.49  0.35  0.03  0.00   2.17  0.54  1.30   0.20亿
# 4    5  003006  百亚股份  27.30  0.00  0.00  0.33   3.98  0.59  2.97   0.46亿
# 5    6  000815   美利云   5.55 -0.54 -0.03  0.18   2.79  0.56  3.23   1.07亿
# 6    7  600308  华泰股份   6.30 -0.63 -0.04  0.16   1.84  0.63  2.21   1.36亿
# 7    8  600966  博汇纸业  15.31 -0.78 -0.12  0.07   1.21  0.69  2.20   2.49亿
# 8    9  002521  齐峰新材   7.18 -0.97 -0.07  0.00   3.21  0.53  1.79   0.98亿
# 9   10  002067  景兴纸业   3.99 -0.99 -0.04  0.25   3.24  0.62  1.99   1.32亿
# 10  11  605007  五洲特纸  21.08 -1.22 -0.26  0.05   6.11  0.49  2.11   0.52亿
# ...

# %%
ak_industry
# Out:
#       name                                               url
# 0   半导体及元件  http://q.10jqka.com.cn/thshy/detail/code/881121/
# 1     白色家电  http://q.10jqka.com.cn/thshy/detail/code/881131/
# 2    保险及其他  http://q.10jqka.com.cn/thshy/detail/code/881156/
# 3     包装印刷  http://q.10jqka.com.cn/thshy/detail/code/881138/
# 4     采掘服务  http://q.10jqka.com.cn/thshy/detail/code/881107/
# ..     ...                                               ...
# 61      证券  http://q.10jqka.com.cn/thshy/detail/code/881157/
# 62      中药  http://q.10jqka.com.cn/thshy/detail/code/881141/
# 63    专用设备  http://q.10jqka.com.cn/thshy/detail/code/881118/
# 64      造纸  http://q.10jqka.com.cn/thshy/detail/code/881137/
# 65  种植业与林业  http://q.10jqka.com.cn/thshy/detail/code/881101/
#
# [66 rows x 2 columns]

# %%
df1 = df[['代码','名称','现价','换手','市盈率']]
df1.columns = ['code', 'name', 'price', 'turnover', 'pe']
df1['board'] = "半导体及元件"
df1
# Out:
#        code  name   price turnover       pe   board
# 0    300077  国民技术     8.7     11.2       --  半导体及元件
# 1    605358   立昂微   88.05    28.47   116.34  半导体及元件
# 2    688595  芯海科技   68.33      9.3       --  半导体及元件
# 3    600601  方正科技    2.92     1.64       --  半导体及元件
# 4    688019  安集科技  253.63     6.11  1641.40  半导体及元件
# ..      ...   ...     ...      ...      ...     ...
# 110  688589   力合微   28.64     7.19   558.24  半导体及元件
# 111  300046  台基股份      23     7.79    83.29  半导体及元件
# 112  000636  风华高科   24.93     6.21    29.97  半导体及元件
# 113  688689  银河微电   27.09    17.17    49.35  半导体及元件
# 114  688536   思瑞浦  483.75     2.92   310.73  半导体及元件
#
# [115 rows x 6 columns]

# %%
for ind in ak_industry['name']:
    df = ak.stock_board_industry_cons_ths(symbol=ind)
    df = df[['代码','名称','现价','换手','市盈率']]
    df.columns = ['code', 'name', 'price', 'turnover', 'pe']
    df['board'] = ind
    df.to_sql("ak_industry_details", engine, if_exists='append')
# Out:
# ...
# 100%|██████████| 2/2 [00:00<00:00,  5.17it/s]

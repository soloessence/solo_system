# %%
from datetime import datetime

import akshare as ak
import backtrader as bt
import matplotlib.pyplot as plt  # 由于 Backtrader 的问题，此处要求 pip install matplotlib==3.2.2
import pandas as pd

plt.rcParams["font.sans-serif"] = ["SimHei"]  # 设置画图时的中文显示
plt.rcParams["axes.unicode_minus"] = False  # 设置画图时的负号显示


import numpy as np
from talib import abstract
import pandas as pd 
import tushare as ts   ## handle the stock data from tushare public api 

from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://solo:solo@localhost:5432/metabase')

# %matplotlib inline

# %%
## 第一种方式， 可以对比一个策略和一基准数据的对比，基于不同的数据

from __future__ import (absolute_import, division, print_function,
                        unicode_literals)


import argparse
import datetime
import random

import backtrader as bt


class EmaCross10And20(bt.SignalStrategy):

    params = dict(ema1=10, ema2=20)

    def notify_order(self, order):
        pass
        # if not order.alive():
        #     print('{} {} {}@{}'.format(
        #         bt.num2date(order.executed.dt),
        #         'buy' if order.isbuy() else 'sell',
        #         order.executed.size,
        #         order.executed.price)
        #     )

    def notify_trade(self, trade):
        if trade.isclosed:
            print('profit {}'.format(trade.pnlcomm))

    def __init__(self):
        ema1 = bt.ind.EMA(period=self.params.ema1)
        ema2 = bt.ind.EMA(period=self.params.ema2)
        crossover = bt.ind.CrossOver(ema1, ema2)

        self.signal_add(bt.SIGNAL_LONG, crossover)


TIMEFRAMES = {
    None: None,
    'days': bt.TimeFrame.Days,
    'weeks': bt.TimeFrame.Weeks,
    'months': bt.TimeFrame.Months,
    'years': bt.TimeFrame.Years,
    'notimeframe': bt.TimeFrame.NoTimeFrame,
}


# def runstrat(args=None):
    
#     args = parse_args(args)

cerebro = bt.Cerebro()
cerebro.broker.set_cash(100000)

#     dkwargs = dict()
#     if args.fromdate:

stock = 'sz002241'
stock1 = 'sz399300' ##沪深300

df = pd.read_sql('''select date as datetime, open, close, high, low, volume 
            from ak_stock_daily where code = '{}' and date<='2021-07-02' order by date asc  '''.format(stock), engine)

# df1 = pd.read_sql('''select date as datetime, open, close, high, low, volume 
#             from ak_stock_daily where code = '{}' and date<='2021-07-09' order by date asc  '''.format(stock1), engine)


df1 = pd.read_sql('''select date as datetime, open, close, high, low, volume 
            from ak_index_daily where code =  '{}' and date<='2021-07-02' and date>='2018-05-24' 
            order by date asc  '''.format(stock1), engine)


# 处理字段命名，以符合 Backtrader 的要求
df.columns = [
    'datetime',
    'open',
    'close',
    'high',
    'low',
    'volume',
]

df.index = pd.to_datetime(df['datetime'])
df1.index = pd.to_datetime(df['datetime'])

data0 = bt.feeds.PandasData(
    dataname=df,
    fromdate=datetime.datetime.strptime('2018-05-24', '%Y-%m-%d'),
    todate=datetime.datetime.strptime('2021-07-09', '%Y-%m-%d')
)



cerebro.adddata(data0, name='Data0')

cerebro.addstrategy(EmaCross10And20)

data1 = bt.feeds.PandasData(
    dataname=df1,
    fromdate=datetime.datetime.strptime('2018-05-24', '%Y-%m-%d'),
    todate=datetime.datetime.strptime('2021-07-09', '%Y-%m-%d'),
    plot=False
)
cerebro.adddata(data1, name='Data1')



# cerebro.addstrategy(St,
#                     period=10,
#                     stake=1000,
#                     printout=False)

# cerebro.addobserver(bt.obs.Trades) 


# cerebro.addobserver(bt.observers.TimeReturn,
#                     timeframe=TIMEFRAMES['notimeframe'])

#benchdata = data0
benchdata = data1


cerebro.addobserver(bt.observers.Benchmark,
                    data=benchdata,
                    timeframe=TIMEFRAMES['notimeframe'])

cerebro.addsizer(bt.sizers.AllInSizerInt)

cerebro.run()

cerebro.plot()
# Out:
# profit 20303.64000000001
# profit 156793.29000000004
# profit -4074.9000000000096
# profit 296778.9
# profit -61364.960000000014
# <img src="data:image/png;base64,..." width="898">
# [[<Figure size 432x288 with 6 Axes>]]

# %%
cerebro.addobserver(bt.obs.Trades, data=data0)

# %%
## 第二种方式的Benchmark， 方便用来做策略与不采取策略的对比

from __future__ import (absolute_import, division, print_function,
                        unicode_literals)


import argparse
import datetime
import random

import backtrader as bt


class St(bt.Strategy):
    params = (
        ('period', 10),
        ('printout', False),
        ('stake', 1000),
    )

    def __init__(self):
        sma = bt.indicators.SMA(self.data, period=self.p.period)
        self.crossover = bt.indicators.CrossOver(self.data, sma)

    def start(self):
        if self.p.printout:
            txtfields = list()
            txtfields.append('Len')
            txtfields.append('Datetime')
            txtfields.append('Open')
            txtfields.append('High')
            txtfields.append('Low')
            txtfields.append('Close')
            txtfields.append('Volume')
            txtfields.append('OpenInterest')
            print(','.join(txtfields))

    def next(self):
        if self.p.printout:
            # Print only 1st data ... is just a check that things are running
            txtfields = list()
            txtfields.append('%04d' % len(self))
            txtfields.append(self.data.datetime.datetime(0).isoformat())
            txtfields.append('%.2f' % self.data0.open[0])
            txtfields.append('%.2f' % self.data0.high[0])
            txtfields.append('%.2f' % self.data0.low[0])
            txtfields.append('%.2f' % self.data0.close[0])
            txtfields.append('%.2f' % self.data0.volume[0])
            txtfields.append('%.2f' % self.data0.openinterest[0])
            print(','.join(txtfields))

        if self.position:
            if self.crossover < 0.0:
                if self.p.printout:
                    print('CLOSE {} @%{}'.format(1000, self.data.close[0]))
                self.close()

        else:
            if self.crossover > 0.0:
                self.buy(size=self.p.stake)
                if self.p.printout:
                    print('BUY   {} @%{}'.format(self.p.stake,
                                                self.data.close[0]))

                    
class EmaCross10And20(bt.SignalStrategy):

    params = dict(ema1=10, ema2=20)

    def notify_order(self, order):
        pass
        # if not order.alive():
        #     print('{} {} {}@{}'.format(
        #         bt.num2date(order.executed.dt),
        #         'buy' if order.isbuy() else 'sell',
        #         order.executed.size,
        #         order.executed.price)
        #     )

    def notify_trade(self, trade):
        if trade.isclosed:
            print('profit {}'.format(trade.pnlcomm))

    def __init__(self):
        ema1 = bt.ind.EMA(period=self.params.ema1)
        ema2 = bt.ind.EMA(period=self.params.ema2)
        crossover = bt.ind.CrossOver(ema1, ema2)

        self.signal_add(bt.SIGNAL_LONG, crossover)
        

TIMEFRAMES = {
    None: None,
    'days': bt.TimeFrame.Days,
    'weeks': bt.TimeFrame.Weeks,
    'months': bt.TimeFrame.Months,
    'years': bt.TimeFrame.Years,
    'notimeframe': bt.TimeFrame.NoTimeFrame,
}





cerebro = bt.Cerebro()
cerebro.broker.set_cash(100000)
cerebro.addsizer(bt.sizers.AllInSizerInt) 



stock = 'sz002241'

df = pd.read_sql('''select date as datetime, open, close, high, low, volume 
            from ak_stock_daily where code = '{}' and date<='2021-07-09' order by date asc  '''.format(stock), engine)

# 处理字段命名，以符合 Backtrader 的要求
df.columns = [
    'datetime',
    'open',
    'close',
    'high',
    'low',
    'volume',
]

df.index = pd.to_datetime(df['datetime'])

data0 = bt.feeds.PandasData(
    dataname=df,
    fromdate=datetime.datetime.strptime('2016-05-24', '%Y-%m-%d'),
    todate=datetime.datetime.strptime('2021-07-09', '%Y-%m-%d'))

cerebro.adddata(data0, name='Data0')

# cerebro.addstrategy(St,
#                     period=10,
#                     stake=1000,
#                     printout=False)

cerebro.addstrategy(EmaCross10And20)


benchdata = data0
cerebro.addobserver(bt.observers.Benchmark,
                    data=benchdata,
                    timeframe=TIMEFRAMES['notimeframe'])

cerebro.run()
cerebro.plot()
# Out:
# profit 20303.64000000001
# profit 156793.29000000004
# profit -4074.9000000000096
# profit 296778.9
# profit -61364.960000000014
# <img src="data:image/png;base64,..." width="944">
# [[<Figure size 432x288 with 6 Axes>]]
